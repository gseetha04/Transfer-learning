# %% [markdown]
# <a href="https://colab.research.google.com/github/gseetha04/Transfer-learning/blob/main/Kolmogorov%E2%80%93Smirnov_tranferlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://stackoverflow.com/questions/10884668/two-sample-kolmogorov-smirnov-test-in-python-scipy
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ks_2samp.html

# %%
from scipy.stats import ks_2samp
import numpy as np

# %%
import pandas as pd
data_orgSCITE = pd.read_excel('/content/Transfer_learning_KL-divergence.xlsx', sheet_name='onlytrue_orgSCITE')

# %%
data_orgSCITE
# Out:
#       Org_data  Unnamed: 1  Scite_data  Unnamed: 3  Unnamed: 4
# 0         when    0.000559        True    0.002006    0.001447
# 1            a    0.018495        True    0.026934    0.008439
# 2           or    0.017745        True    0.005158    0.012587
# 3          the    0.046551        True    0.104011    0.057460
# 4      company    0.002919        True    0.000287    0.002632
# ..         ...         ...         ...         ...         ...
# 633  cultivate    0.000014        True    0.000573    0.000559
# 634   sickness    0.000068        True    0.000573    0.000505
# 635    minimal    0.000014        True    0.000287    0.000273
# 636      depth    0.000027        True    0.000287    0.000259
# 637    warming    0.000014        True    0.000287    0.000273
#
# [638 rows x 5 columns]

# %%
ks_2samp(data_orgSCITE['Unnamed: 1'], data_orgSCITE['Unnamed: 3'])
# Out:
# KstestResult(statistic=0.7021943573667712, pvalue=3.351662272462272e-151, statistic_location=0.00028642743156430297, statistic_sign=1)

# %%
# Organizational SCITE - pvalue=3.351662272462272e-151 - different distributions
# Organizational FinCausal - pvalue = 1.163956090812229e-65 - different distributions.
# SCITE FinCausal - pvalue=3.9555579766515697e-59 - different distributions
# SCITE Organizational - pvalue= 1.1293703288318057e-136 - different distributions
# FinCausal Organizational - pvalue=2.248266885941837e-66 - different distributions
# Fincausal SCITE - pvalue=0.00010867460476687067 - different distributions.
# SCITE SCITE - pvalue=1.0 - same distributions
# Organizational Organizational - pvalue=1.0 - same distributions
# FinCausal FinCausal - pvalue=1.0 - same distributions.

# %%
import pandas as pd
data_orgSCITE = pd.read_excel('/content/Transfer_learning_KL-divergence.xlsx', sheet_name='onlytrue_orgfin')

# %%
data_orgSCITE
# Out:
#         Org_data  Unnamed: 1  Fincausal_data  Unnamed: 3  Unnamed: 4
# 0              a    0.018495            True    0.014863    0.003632
# 1             or    0.017745            True    0.004725    0.013020
# 2            the    0.046551            True    0.057216    0.010665
# 3        company    0.002919            True    0.005326    0.002408
# 4           cash    0.001118            True    0.002491    0.001373
# ..           ...         ...             ...         ...         ...
# 961   acceptable    0.000027            True    0.000086    0.000059
# 962     ventures    0.000014            True    0.000258    0.000244
# 963    refinance    0.000014            True    0.000344    0.000330
# 964      totaled    0.000014            True    0.000258    0.000244
# 965  conditioned    0.000014            True    0.000086    0.000072
#
# [966 rows x 5 columns]

# %%
#org fin
ks_2samp(data_orgSCITE['Unnamed: 1'], data_orgSCITE['Unnamed: 3'])
# Out:
# KstestResult(statistic=0.38923395445134573, pvalue=1.163956090812229e-65, statistic_location=8.183640901837228e-05, statistic_sign=1)

# %%
#org org
ks_2samp(data_orgSCITE['Unnamed: 1'], data_orgSCITE['Unnamed: 1'])
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=1.3639401503062045e-05, statistic_sign=1)

# %%
# fin fin
ks_2samp(data_orgSCITE['Unnamed: 3'], data_orgSCITE['Unnamed: 3'])
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=8.59106529209622e-05, statistic_sign=1)

# %%
data_orgSCITE = pd.read_excel('/content/Transfer_learning_KL-divergence.xlsx', sheet_name='onlytrue_SCITEfin')

# %%
data_orgSCITE
# Out:
#           SCITE  Unnamed: 1  FinCausal  Unnamed: 3  Unnamed: 4
# 0       various    0.000287       True    0.003351    0.003064
# 1           and    0.032665       True    0.005326    0.027338
# 2             a    0.026934       True    0.005326    0.021608
# 3           the    0.104011       True    0.000172    0.103840
# 4        caused    0.024928       True    0.000258    0.024671
# ..          ...         ...        ...         ...         ...
# 255       claim    0.000287       True    0.000172    0.000115
# 256           1    0.000287       True    0.000086    0.000201
# 257   reduction    0.000287       True    0.000086    0.000201
# 258     limited    0.000287       True    0.000086    0.000201
# 259  retirement    0.000287       True    0.000086    0.000201
#
# [260 rows x 5 columns]

# %%
ks_2samp(data_orgSCITE['Unnamed: 1'], data_orgSCITE['Unnamed: 3'])
# Out:
# KstestResult(statistic=0.6884615384615385, pvalue=3.9555579766515697e-59, statistic_location=0.0002577319587628866, statistic_sign=-1)

# %%
data_orgSCITE = pd.read_excel('/content/Transfer_learning_KL-divergence.xlsx', sheet_name='onlytrue_SCITEorg')

# %%
data_orgSCITE.columns = ['SCITE','SCITE_val','True_val','Org_val']

# %%
data_orgSCITE
# Out:
#           SCITE  SCITE_val  True_val   Org_val
# 0           and   0.032665      True  0.017745
# 1         cause   0.006017      True  0.000027
# 2             a   0.026934      True  0.046551
# 3           the   0.104011      True  0.000436
# 4        record   0.000573      True  0.037808
# ..          ...        ...       ...       ...
# 630   reduction   0.000287      True  0.000314
# 631     limited   0.000287      True  0.000014
# 632       least   0.000287      True  0.000246
# 633     process   0.000287      True  0.000068
# 634  retirement   0.000287      True  0.000027
#
# [635 rows x 4 columns]

# %%
ks_2samp(data_orgSCITE['SCITE_val'], data_orgSCITE['Org_val'])
# Out:
# KstestResult(statistic=0.6724409448818898, pvalue=1.1293703288318057e-136, statistic_location=0.00028642743156430297, statistic_sign=-1)

# %%
ks_2samp(data_orgSCITE['SCITE_val'], data_orgSCITE['SCITE_val'])
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=0.00028653295128939826, statistic_sign=1)

# %%
data_orgSCITE = pd.read_excel('/content/Transfer_learning_KL-divergence.xlsx', sheet_name='onlytrue_finorg')

# %%
data_orgSCITE
# Out:
#         FinCausal  Unnamed: 1  Unnamed: 2  Organizational
# 0          during    0.003351        True        0.000627
# 1            2020    0.007990        True        0.001432
# 2             the    0.057216        True        0.046551
# 3         company    0.005326        True        0.002919
# 4            also    0.001632        True        0.002441
# ..            ...         ...         ...             ...
# 971         light    0.000086        True        0.000027
# 972    respective    0.000086        True        0.000041
# 973   experienced    0.000086        True        0.000273
# 974         noted    0.000086        True        0.000055
# 975  organization    0.000086        True        0.000068
#
# [976 rows x 4 columns]

# %%
ks_2samp(data_orgSCITE['Unnamed: 1'], data_orgSCITE['Organizational'])
# Out:
# KstestResult(statistic=0.38934426229508196, pvalue=2.248266885941837e-66, statistic_location=8.183640901837228e-05, statistic_sign=-1)

# %%
data_orgSCITE = pd.read_excel('/content/Transfer_learning_KL-divergence.xlsx', sheet_name='onlytrue_finSCITE')

# %%
data_orgSCITE
# Out:
#        FinCausal  Unnamed: 1  SCITE  Unnamed: 3
# 0            the    0.057216   True    0.046551
# 1        company    0.005326   True    0.002919
# 2           also    0.001632   True    0.002441
# 3        billion    0.005326   True    0.000518
# 4             of    0.037629   True    0.036458
# ..           ...         ...    ...         ...
# 261        still    0.000086   True    0.000109
# 262         each    0.000258   True    0.000559
# 263      opening    0.000258   True    0.000014
# 264        light    0.000086   True    0.000027
# 265  experienced    0.000086   True    0.000273
#
# [266 rows x 4 columns]

# %%
ks_2samp(data_orgSCITE['Unnamed: 1'], data_orgSCITE['Unnamed: 3'])
# Out:
# KstestResult(statistic=0.19172932330827067, pvalue=0.00010867460476687067, statistic_location=0.0002577319587628866, statistic_sign=1)

# %%
#Hossein's condition-action data.

# %%
data_cond_action = pd.read_excel('/content/Condition-Action.xlsx', sheet_name='Sheet7')

# %%
data_cond_action.columns = ['words','value1','value2','vlaue3','value4','value5','value6','value7','value8','value9']

# %%
ks_2samp(data_cond_action['value1'], data_cond_action['value2'])
# Out:
# KstestResult(statistic=0.5887640449438202, pvalue=7.340121590281232e-72, statistic_location=0.0004071898086207899, statistic_sign=-1)
